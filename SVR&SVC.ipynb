# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
d = pd.read_csv('/content/iris - iris.csv')
d
# Out:
#      sepal length in cm  sepal width in cm  petal length in cm  \
# 0                   5.1                3.5                 1.4
# 1                   4.9                3.0                 1.4
# 2                   4.7                3.2                 1.3
# 3                   4.6                3.1                 1.5
# 4                   5.0                3.6                 1.4
# ..                  ...                ...                 ...
# 145                 6.7                3.0                 5.2
# 146                 6.3                2.5                 5.0
# 147                 6.5                3.0                 5.2
# 148                 6.2                3.4                 5.4
# 149                 5.9                3.0                 5.1
#
#      petal width in cm           class
# 0                  0.2     Iris-setosa
# 1                  0.2     Iris-setosa
# 2                  0.2     Iris-setosa
# 3                  0.2     Iris-setosa
# 4                  0.2     Iris-setosa
# ..                 ...             ...
# 145                2.3  Iris-virginica
# 146                1.9  Iris-virginica
# 147                2.0  Iris-virginica
# 148                2.3  Iris-virginica
# 149                1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
d.isna().sum()
# Out:
# sepal length in cm    0
# sepal width in cm     0
# petal length in cm    0
# petal width in cm     0
# class                 0
# dtype: int64

# %%
import matplotlib.image as mping
img=mping.imread('/content/iris_types.jpg')
plt.imshow(img)
plt.show()

# %%
#Spliting the dataset in independent and dependent variables
X = d.iloc[:,:4].values
y = d['class'].values

# %%
from sklearn.model_selection import  train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
# Fitting Multiclass Logistic Classification to the Training set
from sklearn.linear_model import LogisticRegression
logisticregression = LogisticRegression()
logisticregression.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logisticregression.predict(X_test)
y_pred=pd.DataFrame(y_pred)
y_pred
# Out:
#                   0
# 0    Iris-virginica
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5   Iris-versicolor
# 6   Iris-versicolor
# 7   Iris-versicolor
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13   Iris-virginica
# 14  Iris-versicolor
# 15   Iris-virginica
# 16      Iris-setosa
# 17   Iris-virginica
# 18   Iris-virginica
# 19   Iris-virginica
# 20      Iris-setosa
# 21      Iris-setosa
# 22   Iris-virginica
# 23  Iris-versicolor
# 24  Iris-versicolor
# 25  Iris-versicolor
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29  Iris-versicolor

# %%
# Feature Scaling to bring the variable in a single scale
#range from -1 to 1
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train=pd.DataFrame(X_train)
X_train
# Out:
#             0         1         2         3
# 0   -1.215701 -1.429818 -0.346218 -0.341330
# 1    2.196793 -0.515953  1.615683  1.001608
# 2    0.978045 -0.059020  0.750139  1.404490
# 3    0.734296 -0.059020  1.096357  1.270196
# 4    1.099920 -0.059020  0.923248  1.135902
# ..        ...       ...       ...       ...
# 115  0.612421  0.397912  0.346218  0.330139
# 116  0.612421 -0.744419  0.807842  0.867314
# 117  0.246796 -0.515953  0.057703  0.061551
# 118 -0.118828 -0.744419  0.115406 -0.341330
# 119  0.978045  0.169446  0.980951  1.538783
#
# [120 rows x 4 columns]

# %%
import seaborn as sns
sns.pairplot(d,hue='class',diag_kind='hist')

# %%
#label encoding
x=d['class']
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
x=l.fit_transform(x)
x=pd.DataFrame(x)
x
# Out:
#      0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 145  2
# 146  2
# 147  2
# 148  2
# 149  2
#
# [150 rows x 1 columns]

# %%
#fit model
from sklearn.svm import SVC
classifier=SVC(kernel='linear',random_state=0)
classifier.fit(X_train,y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
c=pd.DataFrame(confusion_matrix(y_test,y_pred))
c
# Out:
#     0  1  2
# 0  15  0  0
# 1   0  8  1
# 2   0  0  6

# %%
#heatmap visulization
import seaborn as sn
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
sn.heatmap(c,annot=True)
# Out:
# <Axes: >

# %%
#accuracy
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9666666666666667

# %%
#classification report
from sklearn.metrics import classification_report as cr
print(cr(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       1.00      0.89      0.94         9
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.96      0.95        30
#    weighted avg       0.97      0.97      0.97        30

# %%
#fit model
from sklearn.svm import SVC
classifier=SVC(kernel='rbf',random_state=0)
classifier.fit(X_train,y_train)
# Out:
# SVC(random_state=0)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
c=pd.DataFrame(confusion_matrix(y_test,y_pred))
c
# Out:
#     0  1  2
# 0  15  0  0
# 1   0  8  1
# 2   0  0  6

# %%
#heatmap
import seaborn as sn
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
sn.heatmap(c,annot=True)
# Out:
# <Axes: >

# %%
#classification report
from sklearn.metrics import classification_report as cr
print(cr(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       1.00      0.89      0.94         9
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.96      0.95        30
#    weighted avg       0.97      0.97      0.97        30

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='poly',random_state=0)
classifier.fit(X_train,y_train)
# Out:
# SVC(kernel='poly', random_state=0)

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
c=pd.DataFrame(confusion_matrix(y_test,y_pred))
c
# Out:
#     0  1  2
# 0  15  0  0
# 1   0  8  1
# 2   0  0  6

# %%
#heatmap
import seaborn as sn
import matplotlib.pyplot as plt
plt.figure(figsize=(7,5))
sn.heatmap(c,annot=True)
# Out:
# <Axes: >

# %%
#classification report
from sklearn.metrics import classification_report as cr
print(cr(y_test,y_pred))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        15
# Iris-versicolor       1.00      0.89      0.94         9
#  Iris-virginica       0.86      1.00      0.92         6
#
#        accuracy                           0.97        30
#       macro avg       0.95      0.96      0.95        30
#    weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# SVR (SUPPORT VECTOR REGRESSION)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_spl

# %%
d=pd.read_csv('/content/salary - salary (3).csv')
d
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3       NaN
# 2               1.5       NaN
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
d.isna().sum()
# Out:
# YearsExperience    0
# Salary             2
# dtype: int64

# %%
d['Salary'].fillna(d['Salary'].mean(),inplace=True)
d
# Out:
#     YearsExperience         Salary
# 0               1.1   39343.000000
# 1               1.3   78434.071429
# 2               1.5   78434.071429
# 3               2.0   43525.000000
# 4               2.2   39891.000000
# 5               2.9   56642.000000
# 6               3.0   60150.000000
# 7               3.2   54445.000000
# 8               3.2   64445.000000
# 9               3.7   57189.000000
# 10              3.9   63218.000000
# 11              4.0   55794.000000
# 12              4.0   56957.000000
# 13              4.1   57081.000000
# 14              4.5   61111.000000
# 15              4.9   67938.000000
# 16              5.1   66029.000000
# 17              5.3   83088.000000
# 18              5.9   81363.000000
# 19              6.0   93940.000000
# 20              6.8   91738.000000
# 21              7.1   98273.000000
# 22              7.9  101302.000000
# 23              8.2  113812.000000
# 24              8.7  109431.000000
# 25              9.0  105582.000000
# 26              9.5  116969.000000
# 27              9.6  112635.000000
# 28             10.3  122391.000000
# 29             10.5  121872.000000

# %%
d.isna()
# Out:
#     YearsExperience  Salary
# 0             False   False
# 1             False   False
# 2             False   False
# 3             False   False
# 4             False   False
# 5             False   False
# 6             False   False
# 7             False   False
# 8             False   False
# 9             False   False
# 10            False   False
# 11            False   False
# 12            False   False
# 13            False   False
# 14            False   False
# 15            False   False
# 16            False   False
# 17            False   False
# 18            False   False
# 19            False   False
# 20            False   False
# 21            False   False
# 22            False   False
# 23            False   False
# 24            False   False
# 25            False   False
# 26            False   False
# 27            False   False
# 28            False   False
# 29            False   False

# %%
#spitting dependent and independent variables
#train and test the dataset
x=d['YearsExperience'].values.reshape(-1, 1)
y=d['Salary'].values
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#Fitting the Simple Linear Regression model to the training dataset
from sklearn.svm import SVR
SVR=SVR(kernel='linear')
SVR.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
y_pred=SVR.predict(x_test)
y_pred=pd.DataFrame(x_test)
y_pred
# Out:
#       0
# 0   1.5
# 1  10.3
# 2   4.1
# 3   3.9
# 4   9.5
# 5   8.7

# %%
x_pred=SVR.predict(x_train)
x_pred=pd.DataFrame(x_pred)
x_pred
# Out:
#            0
# 0   67184.06
# 1   66939.90
# 2   66996.58
# 3   67109.94
# 4   66891.94
# 5   66987.86
# 6   66905.02
# 7   66961.70
# 8   67123.02
# 9   67061.98
# 10  66822.18
# 11  67223.30
# 12  66896.30
# 13  66861.42
# 14  67022.74
# 15  67027.10
# 16  66926.82
# 17  66905.02
# 18  67157.90
# 19  66852.70
# 20  66813.46
# 21  67075.06
# 22  66979.14
# 23  66939.90

# %%
#visulization of train dataset
plt.scatter(x_train, y_train, color = "red")
plt.plot(x_train,x_pred, color = "black")
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.title("Salary vs Experience (Training Set)")
plt.show()

# %%
#visualizing the Test set results
import matplotlib.pyplot as mtp
mtp.scatter(x_test, y_test, color="blue")
mtp.plot(x_train, x_pred, color="red")
mtp.title("Salary vs Experience (Test Dataset)")
mtp.xlabel("Years of Experience")
mtp.ylabel("Salary(In Rupees)")
mtp.show()

# %%
#Calculating Mean Squared error
from sklearn.metrics import mean_squared_error,r2_score
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 9005877220.557993

# %%
# variance score: 1 means perfect prediction
from sklearn.metrics import r2_score
print('Variance score: ',r2_score(x_test, y_test))
# Out:
# Variance score:  -823289942.9819394

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 9005877220.557993
